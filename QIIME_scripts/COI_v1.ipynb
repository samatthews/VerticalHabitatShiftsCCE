# %%
#import the qiime2 python module to allow for inline visualizations

import qiime2 as q2

# %%
#which version of qiime2 and python are we using?

# !qiime info
# Out:
# System versions
# Python version: 3.6.10
# QIIME 2 release: 2020.6
# QIIME 2 version: 2020.6.0
# q2cli version: 2020.6.0
#
# Installed plugins
# alignment: 2020.6.0
# composition: 2020.6.0
# cutadapt: 2020.6.0
# dada2: 2020.6.0
# deblur: 2020.6.0
# demux: 2020.6.0
# diversity: 2020.6.0
# diversity-lib: 2020.6.0
# emperor: 2020.6.0
# feature-classifier: 2020.6.0
# feature-table: 2020.6.0
# fragment-insertion: 2020.6.0
# gneiss: 2020.6.0
# longitudinal: 2020.6.0
# metadata: 2020.6.0
# phylogeny: 2020.6.0
# quality-control: 2020.6.0
# quality-filter: 2020.6.0
# sample-classifier: 2020.6.0
# taxa: 2020.6.0
# types: 2020.6.0
# vsearch: 2020.6.0
#
# Application config directory
# /Users/stephaniematthews/miniconda3/envs/qiime2-2020.6/var/q2cli
#
# Getting help
# To get help with QIIME 2, visit https://qiime2.org

# %% [markdown]
# First, import the paired forward and reverse sequences with a manifest file. Manifest prepared by listing all files in bash and formatting in Excel.

# %%
#Import the fastq files into a QIIME2 artifact 

# !qiime tools import \
  --type 'SampleData[PairedEndSequencesWithQuality]' \
  --input-path leray_manifest_run1_grid.csv \
  --output-path COI_1-paired-end-demux.qza \
  --input-format PairedEndFastqManifestPhred33
# Out:
# Imported leray_manifest_run1_grid.csv as PairedEndFastqManifestPhred33 to COI_1-paired-end-demux.qza

# %% [markdown]
# Trim reverse primers
# See: https://docs.qiime2.org/2020.6/plugins/available/cutadapt/trim-paired/
# default is to match IUPAC wildcards ( --p-match-adapter-wildcards T )
# - these should be the F/R marker primers
# - cannot handle inosine bases; using N instead
# - f primer/ r primer
# - or could just trim off length of primer+barcode? this provides a test of primer accuracy/error

# %%
# !qiime cutadapt trim-paired \
    --i-demultiplexed-sequences COI_1-paired-end-demux.qza \
    --p-front-f '^GGWACWGGWTGAACWGTWTAYCCYCC' \
    --p-front-r '^TANACYTCNGGRTGNCCRAARAAYCA' \
    --o-trimmed-sequences COI_1-demux-pairedend-trimmed1.qza \
    --verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S001_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S001_1_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S001_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S001_1_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S001_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S001_1_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S001_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S001_1_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:02        32,393 reads  @     75.9 µs/read;   0.79 M reads/minute
# Finished in 2.46 s (76 us/read; 0.79 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             32,393
#   Read 1 with adapter:                  32,365 (99.9%)
#   Read 2 with adapter:                  32,122 (99.2%)
# Pairs written (passing filters):        32,393 (100.0%)
#
# Total basepairs processed:    19,107,367 bp
#   Read 1:     9,555,543 bp
#   Read 2:     9,551,824 bp
# Total written (filtered):     17,431,725 bp (91.2%)
#   Read 1:     8,713,815 bp
#   Read 2:     8,717,910 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 32365 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	16	0.0	2	0 0 16
# 25	288	0.0	2	0 277 11
# 26	31637	0.0	2	30730 876 31
# 27	290	0.0	2	0 275 15
# 28	134	0.0	2	0 0 134
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 32122 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	37	0.0	2	0 0 37
# 25	1379	0.0	2	0 1347 32
# 26	30527	0.0	2	29836 673 18
# 27	163	0.0	2	0 159 4
# 28	16	0.0	2	0 0 16
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S002_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S002_3_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S002_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S002_3_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S002_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S002_3_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S002_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S002_3_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        57,557 reads  @     76.8 µs/read;   0.78 M reads/minute
# Finished in 4.43 s (77 us/read; 0.78 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             57,557
#   Read 1 with adapter:                  57,517 (99.9%)
#   Read 2 with adapter:                  57,309 (99.6%)
# Pairs written (passing filters):        57,557 (100.0%)
#
# Total basepairs processed:    33,955,633 bp
#   Read 1:    16,978,797 bp
#   Read 2:    16,976,836 bp
# Total written (filtered):     30,970,955 bp (91.2%)
#   Read 1:    15,483,296 bp
#   Read 2:    15,487,659 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 57517 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	44	0.0	2	0 0 44
# 25	526	0.0	2	0 512 14
# 26	56440	0.0	2	55015 1406 19
# 27	341	0.0	2	0 330 11
# 28	166	0.0	2	0 0 166
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 57309 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	50	0.0	2	0 0 50
# 25	1041	0.0	2	0 1006 35
# 26	55949	0.0	2	54468 1423 58
# 27	254	0.0	2	0 235 19
# 28	15	0.0	2	0 0 15
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S003_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S003_5_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S003_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S003_5_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S003_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S003_5_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S003_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S003_5_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:05        69,039 reads  @     80.5 µs/read;   0.75 M reads/minute
# Finished in 5.56 s (81 us/read; 0.75 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             69,039
#   Read 1 with adapter:                  68,994 (99.9%)
#   Read 2 with adapter:                  68,479 (99.2%)
# Pairs written (passing filters):        69,039 (100.0%)
#
# Total basepairs processed:    40,731,067 bp
#   Read 1:    20,365,377 bp
#   Read 2:    20,365,690 bp
# Total written (filtered):     37,158,126 bp (91.2%)
#   Read 1:    18,571,565 bp
#   Read 2:    18,586,561 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 68994 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	46	0.0	2	0 0 46
# 25	729	0.0	2	0 708 21
# 26	67632	0.0	2	66043 1557 32
# 27	385	0.0	2	0 371 14
# 28	202	0.0	2	0 0 202
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 68479 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	48	0.0	2	0 0 48
# 25	1542	0.0	2	0 1504 38
# 26	66589	0.0	2	65050 1475 64
# 27	287	0.0	2	0 278 9
# 28	13	0.0	2	0 0 13
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S004_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S004_7_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S004_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S004_7_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S004_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S004_7_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S004_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S004_7_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:03        34,547 reads  @     92.9 µs/read;   0.65 M reads/minute
# Finished in 3.22 s (93 us/read; 0.64 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             34,547
#   Read 1 with adapter:                  34,522 (99.9%)
#   Read 2 with adapter:                  33,737 (97.7%)
# Pairs written (passing filters):        34,546 (100.0%)
#
# Total basepairs processed:    20,267,932 bp
#   Read 1:    10,191,101 bp
#   Read 2:    10,076,831 bp
# Total written (filtered):     18,493,406 bp (91.2%)
#   Read 1:     9,293,443 bp
#   Read 2:     9,199,963 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 34522 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	29	0.0	2	0 0 29
# 25	374	0.0	2	0 362 12
# 26	33903	0.0	2	33049 836 18
# 27	183	0.0	2	0 171 12
# 28	33	0.0	2	0 0 33
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 33737 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	29	0.0	2	0 0 29
# 25	416	0.0	2	0 397 19
# 26	33128	0.0	2	32112 962 54
# 27	148	0.0	2	0 139 9
# 28	16	0.0	2	0 0 16
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S005_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S005_9_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S005_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S005_9_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S005_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S005_9_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S005_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S005_9_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [   8=-------] 00:00:07        73,292 reads  @    105.1 µs/read;   0.57 M reads/minute
# Finished in 7.71 s (105 us/read; 0.57 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             73,292
#   Read 1 with adapter:                  73,230 (99.9%)
#   Read 2 with adapter:                  68,191 (93.0%)
# Pairs written (passing filters):        73,290 (100.0%)
#
# Total basepairs processed:    42,370,803 bp
#   Read 1:    21,619,064 bp
#   Read 2:    20,751,739 bp
# Total written (filtered):     38,694,944 bp (91.3%)
#   Read 1:    19,715,089 bp
#   Read 2:    18,979,855 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 73230 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	65	0.0	2	0 0 65
# 25	898	0.0	2	0 867 31
# 26	71889	0.0	2	70098 1754 37
# 27	271	0.0	2	0 267 4
# 28	107	0.0	2	0 0 107
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 68191 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	68	0.0	2	0 0 68
# 25	1314	0.0	2	0 1251 63
# 26	66501	0.0	2	64477 1916 108
# 27	248	0.0	2	0 226 22
# 28	60	0.0	2	0 0 60
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S006_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S006_11_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S006_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S006_11_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S006_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S006_11_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S006_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S006_11_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:06        73,240 reads  @     94.1 µs/read;   0.64 M reads/minute
# Finished in 6.90 s (94 us/read; 0.64 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             73,240
#   Read 1 with adapter:                  73,159 (99.9%)
#   Read 2 with adapter:                  72,895 (99.5%)
# Pairs written (passing filters):        73,239 (100.0%)
#
# Total basepairs processed:    43,170,391 bp
#   Read 1:    21,603,403 bp
#   Read 2:    21,566,988 bp
# Total written (filtered):     39,374,532 bp (91.2%)
#   Read 1:    19,701,553 bp
#   Read 2:    19,672,979 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 73159 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	76	0.0	2	0 0 76
# 25	923	0.0	2	0 898 25
# 26	71748	0.0	2	69884 1832 32
# 27	302	0.0	2	0 291 11
# 28	110	0.0	2	0 0 110
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 72895 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	82	0.0	2	0 0 82
# 25	1447	0.0	2	0 1408 39
# 26	71068	0.0	2	69116 1869 83
# 27	246	0.0	2	0 237 9
# 28	52	0.0	2	0 0 52
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S007_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S007_13_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S007_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S007_13_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S007_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S007_13_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S007_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S007_13_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:07        72,146 reads  @     97.0 µs/read;   0.62 M reads/minute
# Finished in 7.01 s (97 us/read; 0.62 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             72,146
#   Read 1 with adapter:                  72,068 (99.9%)
#   Read 2 with adapter:                  72,005 (99.8%)
# Pairs written (passing filters):        72,146 (100.0%)
#
# Total basepairs processed:    42,557,841 bp
#   Read 1:    21,278,823 bp
#   Read 2:    21,279,018 bp
# Total written (filtered):     38,812,603 bp (91.2%)
#   Read 1:    19,405,303 bp
#   Read 2:    19,407,300 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 72068 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	88	0.0	2	0 0 88
# 25	872	0.0	2	0 843 29
# 26	70524	0.0	2	68636 1860 28
# 27	368	0.0	2	0 348 20
# 28	216	0.0	2	0 0 216
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 72005 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	35	0.0	2	0 0 35
# 25	792	0.0	2	0 758 34
# 26	70797	0.0	2	68826 1898 73
# 27	312	0.0	2	0 292 20
# 28	69	0.0	2	0 0 69
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S008_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S008_15_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S008_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S008_15_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S008_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S008_15_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S008_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S008_15_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:06        63,056 reads  @     98.9 µs/read;   0.61 M reads/minute
# Finished in 6.24 s (99 us/read; 0.61 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             63,056
#   Read 1 with adapter:                  62,981 (99.9%)
#   Read 2 with adapter:                  62,934 (99.8%)
# Pairs written (passing filters):        63,056 (100.0%)
#
# Total basepairs processed:    37,196,828 bp
#   Read 1:    18,596,411 bp
#   Read 2:    18,600,417 bp
# Total written (filtered):     33,923,493 bp (91.2%)
#   Read 1:    16,958,911 bp
#   Read 2:    16,964,582 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 62981 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	63	0.0	2	0 0 63
# 25	636	0.0	2	0 617 19
# 26	61698	0.0	2	60090 1566 42
# 27	412	0.0	2	0 396 16
# 28	172	0.0	2	0 0 172
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 62934 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	51	0.0	2	0 0 51
# 25	677	0.0	2	0 651 26
# 26	61915	0.0	2	60408 1457 50
# 27	252	0.0	2	0 241 11
# 28	39	0.0	2	0 0 39
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S009_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S009_17_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S009_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S009_17_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S009_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S009_17_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S009_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S009_17_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        42,359 reads  @     92.0 µs/read;   0.65 M reads/minute
# Finished in 3.90 s (92 us/read; 0.65 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             42,359
#   Read 1 with adapter:                  42,324 (99.9%)
#   Read 2 with adapter:                  42,000 (99.2%)
# Pairs written (passing filters):        42,359 (100.0%)
#
# Total basepairs processed:    24,986,505 bp
#   Read 1:    12,495,588 bp
#   Read 2:    12,490,917 bp
# Total written (filtered):     22,795,704 bp (91.2%)
#   Read 1:    11,395,041 bp
#   Read 2:    11,400,663 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 42324 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	28	0.0	2	0 0 28
# 25	304	0.0	2	0 292 12
# 26	41663	0.0	2	40625 1014 24
# 27	175	0.0	2	0 168 7
# 28	154	0.0	2	0 0 154
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 42000 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	60	0.0	2	0 0 60
# 25	1868	0.0	2	0 1814 54
# 26	39879	0.0	2	38963 894 22
# 27	144	0.0	2	0 137 7
# 28	49	0.0	2	0 0 49
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S010_18_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S010_19_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S010_18_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S010_19_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S010_18_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S010_19_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S010_18_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S010_19_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        59,219 reads  @     83.6 µs/read;   0.72 M reads/minute
# Finished in 4.96 s (84 us/read; 0.72 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             59,219
#   Read 1 with adapter:                  59,180 (99.9%)
#   Read 2 with adapter:                  59,039 (99.7%)
# Pairs written (passing filters):        59,219 (100.0%)
#
# Total basepairs processed:    34,937,638 bp
#   Read 1:    17,469,140 bp
#   Read 2:    17,468,498 bp
# Total written (filtered):     31,864,726 bp (91.2%)
#   Read 1:    15,930,406 bp
#   Read 2:    15,934,320 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 59180 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	50	0.0	2	0 0 50
# 25	441	0.0	2	0 425 16
# 26	58261	0.0	2	56930 1313 18
# 27	261	0.0	2	0 254 7
# 28	167	0.0	2	0 0 167
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 59039 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	47	0.0	2	0 0 47
# 25	996	0.0	2	0 971 25
# 26	57754	0.0	2	56435 1276 43
# 27	230	0.0	2	0 209 21
# 28	12	0.0	2	0 0 12
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S011_20_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S011_21_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S011_20_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S011_21_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S011_20_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S011_21_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S011_20_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S011_21_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        48,187 reads  @     80.2 µs/read;   0.75 M reads/minute
# Finished in 3.87 s (80 us/read; 0.75 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             48,187
#   Read 1 with adapter:                  48,150 (99.9%)
#   Read 2 with adapter:                  48,039 (99.7%)
# Pairs written (passing filters):        48,186 (100.0%)
#
# Total basepairs processed:    28,428,516 bp
#   Read 1:    14,214,601 bp
#   Read 2:    14,213,915 bp
# Total written (filtered):     25,928,360 bp (91.2%)
#   Read 1:    12,962,713 bp
#   Read 2:    12,965,647 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 48150 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	33	0.0	2	0 0 33
# 25	420	0.0	2	0 404 16
# 26	47351	0.0	2	46243 1088 20
# 27	218	0.0	2	0 217 1
# 28	128	0.0	2	0 0 128
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 48039 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	38	0.0	2	0 0 38
# 25	1139	0.0	2	0 1107 32
# 26	46671	0.0	2	45559 1081 31
# 27	182	0.0	2	0 174 8
# 28	9	0.0	2	0 0 9
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S012_22_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S012_23_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S012_22_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S012_23_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S012_22_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S012_23_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S012_22_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S012_23_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        41,308 reads  @     98.9 µs/read;   0.61 M reads/minute
# Finished in 4.09 s (99 us/read; 0.61 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             41,308
#   Read 1 with adapter:                  40,966 (99.2%)
#   Read 2 with adapter:                  40,406 (97.8%)
# Pairs written (passing filters):        41,307 (100.0%)
#
# Total basepairs processed:    24,244,733 bp
#   Read 1:    12,185,401 bp
#   Read 2:    12,059,332 bp
# Total written (filtered):     22,129,198 bp (91.3%)
#   Read 1:    11,120,068 bp
#   Read 2:    11,009,130 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 40966 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	24	0.0	2	0 0 24
# 25	353	0.0	2	0 342 11
# 26	40333	0.0	2	39294 1024 15
# 27	163	0.0	2	0 152 11
# 28	93	0.0	2	0 0 93
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 40406 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	29	0.0	2	0 0 29
# 25	509	0.0	2	0 485 24
# 26	39665	0.0	2	38406 1178 81
# 27	193	0.0	2	0 182 11
# 28	10	0.0	2	0 0 10
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S013_24_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S013_25_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S013_24_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S013_25_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S013_24_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S013_25_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S013_24_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S013_25_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [   8=-------] 00:00:08        81,229 reads  @    107.0 µs/read;   0.56 M reads/minute
# Finished in 8.70 s (107 us/read; 0.56 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             81,229
#   Read 1 with adapter:                  81,120 (99.9%)
#   Read 2 with adapter:                  76,307 (93.9%)
# Pairs written (passing filters):        81,228 (100.0%)
#
# Total basepairs processed:    47,095,166 bp
#   Read 1:    23,961,272 bp
#   Read 2:    23,133,894 bp
# Total written (filtered):     43,003,473 bp (91.3%)
#   Read 1:    21,852,595 bp
#   Read 2:    21,150,878 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 81120 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	62	0.0	2	0 0 62
# 25	825	0.0	2	0 791 34
# 26	79823	0.0	2	77683 2110 30
# 27	314	0.0	2	0 301 13
# 28	96	0.0	2	0 0 96
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 76307 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	76	0.0	2	0 0 76
# 25	1472	0.0	2	0 1425 47
# 26	74421	0.0	2	72022 2262 137
# 27	287	0.0	2	0 268 19
# 28	51	0.0	2	0 0 51
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S014_26_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S014_27_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S014_26_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S014_27_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S014_26_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S014_27_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S014_26_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S014_27_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [  8<--------] 00:00:05        50,951 reads  @    101.4 µs/read;   0.59 M reads/minute
# Finished in 5.17 s (101 us/read; 0.59 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             50,951
#   Read 1 with adapter:                  50,915 (99.9%)
#   Read 2 with adapter:                  50,763 (99.6%)
# Pairs written (passing filters):        50,948 (100.0%)
#
# Total basepairs processed:    30,034,833 bp
#   Read 1:    15,029,291 bp
#   Read 2:    15,005,542 bp
# Total written (filtered):     27,391,620 bp (91.2%)
#   Read 1:    13,705,003 bp
#   Read 2:    13,686,617 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 50915 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	54	0.0	2	0 0 54
# 25	499	0.0	2	0 484 15
# 26	50120	0.0	2	48760 1343 17
# 27	186	0.0	2	0 181 5
# 28	56	0.0	2	0 0 56
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 50763 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	65	0.0	2	0 0 65
# 25	993	0.0	2	0 947 46
# 26	49518	0.0	2	48218 1247 53
# 27	164	0.0	2	0 161 3
# 28	23	0.0	2	0 0 23
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S015_28_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S015_29_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S015_28_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S015_29_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S015_28_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S015_29_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S015_28_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S015_29_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:05        57,420 reads  @     93.0 µs/read;   0.65 M reads/minute
# Finished in 5.34 s (93 us/read; 0.64 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             57,420
#   Read 1 with adapter:                  57,365 (99.9%)
#   Read 2 with adapter:                  57,296 (99.8%)
# Pairs written (passing filters):        57,419 (100.0%)
#
# Total basepairs processed:    33,874,877 bp
#   Read 1:    16,938,524 bp
#   Read 2:    16,936,353 bp
# Total written (filtered):     30,893,918 bp (91.2%)
#   Read 1:    15,447,241 bp
#   Read 2:    15,446,677 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 57365 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	48	0.0	2	0 0 48
# 25	567	0.0	2	0 545 22
# 26	56400	0.0	2	54844 1529 27
# 27	244	0.0	2	0 231 13
# 28	106	0.0	2	0 0 106
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 57296 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	45	0.0	2	0 0 45
# 25	622	0.0	2	0 588 34
# 26	56274	0.0	2	54574 1623 77
# 27	287	0.0	2	0 271 16
# 28	68	0.0	2	0 0 68
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S016_30_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S016_31_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S016_30_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S016_31_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S016_30_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S016_31_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S016_30_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S016_31_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        55,126 reads  @     89.1 µs/read;   0.67 M reads/minute
# Finished in 4.92 s (89 us/read; 0.67 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             55,126
#   Read 1 with adapter:                  55,081 (99.9%)
#   Read 2 with adapter:                  55,058 (99.9%)
# Pairs written (passing filters):        55,126 (100.0%)
#
# Total basepairs processed:    32,523,930 bp
#   Read 1:    16,262,074 bp
#   Read 2:    16,261,856 bp
# Total written (filtered):     29,660,878 bp (91.2%)
#   Read 1:    14,830,183 bp
#   Read 2:    14,830,695 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 55081 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	39	0.0	2	0 0 39
# 25	527	0.0	2	0 516 11
# 26	54197	0.0	2	52715 1449 33
# 27	246	0.0	2	0 239 7
# 28	72	0.0	2	0 0 72
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 55058 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	42	0.0	2	0 0 42
# 25	558	0.0	2	0 544 14
# 26	54199	0.0	2	52825 1333 41
# 27	223	0.0	2	0 214 9
# 28	36	0.0	2	0 0 36
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S017_32_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S017_33_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S017_32_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S017_33_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S017_32_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S017_33_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S017_32_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S017_33_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        47,055 reads  @     90.4 µs/read;   0.66 M reads/minute
# Finished in 4.26 s (91 us/read; 0.66 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             47,055
#   Read 1 with adapter:                  46,927 (99.7%)
#   Read 2 with adapter:                  46,618 (99.1%)
# Pairs written (passing filters):        47,055 (100.0%)
#
# Total basepairs processed:    27,750,894 bp
#   Read 1:    13,876,162 bp
#   Read 2:    13,874,732 bp
# Total written (filtered):     25,320,683 bp (91.2%)
#   Read 1:    12,656,038 bp
#   Read 2:    12,664,645 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 46927 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	38	0.0	2	0 0 38
# 25	402	0.0	2	0 386 16
# 26	46132	0.0	2	44861 1249 22
# 27	210	0.0	2	0 200 10
# 28	145	0.0	2	0 0 145
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 46618 times
#
# No. of allowed errors:
# ...
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        62,168 reads  @     72.9 µs/read;   0.82 M reads/minute
# Finished in 4.54 s (73 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             62,168
#   Read 1 with adapter:                  62,110 (99.9%)
#   Read 2 with adapter:                  62,085 (99.9%)
# Pairs written (passing filters):        62,168 (100.0%)
#
# Total basepairs processed:    36,673,000 bp
#   Read 1:    18,336,271 bp
#   Read 2:    18,336,729 bp
# Total written (filtered):     33,444,604 bp (91.2%)
#   Read 1:    16,721,687 bp
#   Read 2:    16,722,917 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 62110 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	50	0.0	2	0 0 50
# 25	480	0.0	2	0 465 15
# 26	61328	0.0	2	59889 1417 22
# 27	200	0.0	2	0 195 5
# 28	52	0.0	2	0 0 52
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 62085 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	40	0.0	2	0 0 40
# 25	591	0.0	2	0 569 22
# 26	61193	0.0	2	59684 1433 76
# 27	249	0.0	2	0 236 13
# 28	12	0.0	2	0 0 12
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S118_228_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S118_229_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S118_228_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S118_229_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S118_228_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S118_229_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S118_228_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S118_229_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:05        79,734 reads  @     69.9 µs/read;   0.86 M reads/minute
# Finished in 5.58 s (70 us/read; 0.86 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             79,734
#   Read 1 with adapter:                  79,657 (99.9%)
#   Read 2 with adapter:                  79,609 (99.8%)
# Pairs written (passing filters):        79,734 (100.0%)
#
# Total basepairs processed:    47,035,147 bp
#   Read 1:    23,517,450 bp
#   Read 2:    23,517,697 bp
# Total written (filtered):     42,895,079 bp (91.2%)
#   Read 1:    21,446,742 bp
#   Read 2:    21,448,337 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 79657 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	60	0.0	2	0 0 60
# 25	690	0.0	2	0 673 17
# 26	78552	0.0	2	76647 1878 27
# 27	274	0.0	2	0 261 13
# 28	81	0.0	2	0 0 81
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 79609 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	60	0.0	2	0 0 60
# 25	781	0.0	2	0 759 22
# 26	78377	0.0	2	76440 1874 63
# 27	355	0.0	2	0 343 12
# 28	36	0.0	2	0 0 36
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S119_230_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S119_231_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S119_230_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S119_231_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S119_230_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S119_231_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S119_230_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S119_231_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [  8<--------] 00:00:05        87,641 reads  @     68.2 µs/read;   0.88 M reads/minute
# Finished in 5.99 s (68 us/read; 0.88 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             87,641
#   Read 1 with adapter:                  87,568 (99.9%)
#   Read 2 with adapter:                  87,489 (99.8%)
# Pairs written (passing filters):        87,641 (100.0%)
#
# Total basepairs processed:    51,700,500 bp
#   Read 1:    25,848,792 bp
#   Read 2:    25,851,708 bp
# Total written (filtered):     47,149,880 bp (91.2%)
#   Read 1:    23,572,432 bp
#   Read 2:    23,577,448 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 87568 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	51	0.0	2	0 0 51
# 25	757	0.0	2	0 735 22
# 26	86377	0.0	2	84293 2044 40
# 27	315	0.0	2	0 303 12
# 28	68	0.0	2	0 0 68
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 87489 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	67	0.0	2	0 0 67
# 25	769	0.0	2	0 750 19
# 26	86235	0.0	2	84138 2026 71
# 27	387	0.0	2	0 374 13
# 28	31	0.0	2	0 0 31
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S120_232_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S120_233_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S120_232_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S120_233_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S120_232_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S120_233_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S120_232_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S120_233_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        61,940 reads  @     70.1 µs/read;   0.86 M reads/minute
# Finished in 4.34 s (70 us/read; 0.86 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             61,940
#   Read 1 with adapter:                  61,876 (99.9%)
#   Read 2 with adapter:                  61,803 (99.8%)
# Pairs written (passing filters):        61,940 (100.0%)
#
# Total basepairs processed:    36,530,798 bp
#   Read 1:    18,270,519 bp
#   Read 2:    18,260,279 bp
# Total written (filtered):     33,316,045 bp (91.2%)
#   Read 1:    16,662,221 bp
#   Read 2:    16,653,824 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 61876 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	54	0.0	2	0 0 54
# 25	725	0.0	2	0 699 26
# 26	60838	0.0	2	59214 1596 28
# 27	163	0.0	2	0 151 12
# 28	96	0.0	2	0 0 96
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 61803 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	50	0.0	2	0 0 50
# 25	636	0.0	2	0 623 13
# 26	60820	0.0	2	59220 1539 61
# 27	281	0.0	2	0 266 15
# 28	16	0.0	2	0 0 16
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S121_234_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S121_235_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S121_234_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S121_235_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S121_234_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S121_235_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S121_234_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S121_235_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:05        74,940 reads  @     67.6 µs/read;   0.89 M reads/minute
# Finished in 5.07 s (68 us/read; 0.89 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             74,940
#   Read 1 with adapter:                  74,868 (99.9%)
#   Read 2 with adapter:                  74,837 (99.9%)
# Pairs written (passing filters):        74,940 (100.0%)
#
# Total basepairs processed:    44,209,135 bp
#   Read 1:    22,106,818 bp
#   Read 2:    22,102,317 bp
# Total written (filtered):     40,317,984 bp (91.2%)
#   Read 1:    20,160,879 bp
#   Read 2:    20,157,105 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 74868 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	54	0.0	2	0 0 54
# 25	833	0.0	2	0 812 21
# 26	73733	0.0	2	71927 1785 21
# 27	184	0.0	2	0 176 8
# 28	64	0.0	2	0 0 64
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 74837 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	54	0.0	2	0 0 54
# 25	796	0.0	2	0 763 33
# 26	73648	0.0	2	71888 1695 65
# 27	324	0.0	2	0 314 10
# 28	15	0.0	2	0 0 15
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S122_236_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S122_237_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S122_236_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S122_237_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S122_236_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-7ct33jwe/S122_237_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S122_236_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-17fe3czy/ee1f4d95-d4e9-4a5b-8a69-00e2dc1e2a8b/data/S122_237_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [  8<--------] 00:00:05        85,904 reads  @     69.4 µs/read;   0.87 M reads/minute
# Finished in 5.96 s (69 us/read; 0.86 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             85,904
#   Read 1 with adapter:                  85,799 (99.9%)
#   Read 2 with adapter:                  85,738 (99.8%)
# Pairs written (passing filters):        85,904 (100.0%)
#
# Total basepairs processed:    50,675,309 bp
#   Read 1:    25,338,831 bp
#   Read 2:    25,336,478 bp
# Total written (filtered):     46,216,532 bp (91.2%)
#   Read 1:    23,108,716 bp
#   Read 2:    23,107,816 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 85799 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	70	0.0	2	0 0 70
# 25	958	0.0	2	0 932 26
# 26	84422	0.0	2	82233 2154 35
# 27	259	0.0	2	0 245 14
# 28	90	0.0	2	0 0 90
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 85738 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	70	0.0	2	0 0 70
# 25	816	0.0	2	0 791 25
# 26	84458	0.0	2	82290 2078 90
# 27	358	0.0	2	0 339 19
# 28	36	0.0	2	0 0 36
# Saved SampleData[PairedEndSequencesWithQuality] to: COI_1-demux-pairedend-trimmed1.qza

# %%
# !qiime demux summarize \
  --i-data COI_1-demux-pairedend-trimmed1.qza \
  --o-visualization COI_1-demux-pairedend-trimmed1.qzv
# Out:
# Saved Visualization to: COI_1-demux-pairedend-trimmed1.qzv

# %%
q2.Visualization.load('COI_1-demux-pairedend-trimmed1.qzv')
# Out:
# <visualization: Visualization uuid: 3bb3501f-3e10-4131-b836-bee6bdb75563>

# %%
#Generate ESVs (Exact Sequence Variants). QIIME2 has two packages available for this. We are using dada2 for our single end reads.
# NOTE: if you are wanting to do paired end reads, you'll use qiime dada2 denoise-paired (https://docs.qiime2.org/2019.7/plugins/available/dada2/denoise-paired/)
# NOTE: if you are wanting to join reads you'll have to use Deblur


# !qiime dada2 denoise-paired \
  --i-demultiplexed-seqs COI_1-demux-pairedend-trimmed1.qza \
  --p-trunc-len-f 260 \
  --p-trunc-len-r 220 \
  --p-pooling-method pseudo \
  --p-chimera-method consensus \
  --p-n-threads 0 \
  --p-n-reads-learn 10000 \
  --o-representative-sequences COI_1-paired-end-demux_rep-seqs-dada2.qza \
  --o-table COI_1-paired-end-demux_table-dada2.qza \
  --o-denoising-stats COI_1-paired-end-demux_stats-dada2.qza
# Out:
# Saved FeatureTable[Frequency] to: COI_1-paired-end-demux_table-dada2.qza
# Saved FeatureData[Sequence] to: COI_1-paired-end-demux_rep-seqs-dada2.qza
# Saved SampleData[DADA2Stats] to: COI_1-paired-end-demux_stats-dada2.qza

# %% [markdown]
# now do it all again for the second and third run

# %%
#Import the fastq files into a QIIME2 artifact 

# !qiime tools import \
  --type 'SampleData[PairedEndSequencesWithQuality]' \
  --input-path leray_manifest_run2_v1.csv \
  --output-path COI_2-paired-end-demux.qza \
  --input-format PairedEndFastqManifestPhred33
# !qiime cutadapt trim-paired \
    --i-demultiplexed-sequences COI_2-paired-end-demux.qza \
    --p-front-f '^GGWACWGGWTGAACWGTWTAYCCYCC' \
    --p-front-r '^TANACYTCNGGRTGNCCRAARAAYCA' \
    --o-trimmed-sequences COI_2-demux-pairedend-trimmed1.qza \
    --verbose
# Out:
# Imported leray_manifest_run2_v1.csv as PairedEndFastqManifestPhred33 to COI_2-paired-end-demux.qza
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S251_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S251_1_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S251_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S251_1_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S251_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S251_1_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S251_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S251_1_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        46,869 reads  @     74.3 µs/read;   0.81 M reads/minute
# Finished in 3.49 s (74 us/read; 0.81 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             46,869
#   Read 1 with adapter:                  46,812 (99.9%)
#   Read 2 with adapter:                  46,776 (99.8%)
# Pairs written (passing filters):        46,869 (100.0%)
#
# Total basepairs processed:    27,650,425 bp
#   Read 1:    13,825,108 bp
#   Read 2:    13,825,317 bp
# Total written (filtered):     25,217,847 bp (91.2%)
#   Read 1:    12,608,002 bp
#   Read 2:    12,609,845 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 46812 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	28	0.0	2	0 0 28
# 25	303	0.0	2	0 286 17
# 26	46212	0.0	2	44741 1430 41
# 27	185	0.0	2	0 175 10
# 28	84	0.0	2	0 0 84
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 46776 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	75	0.0	2	0 0 75
# 25	763	0.0	2	0 742 21
# 26	45750	0.0	2	44816 902 32
# 27	167	0.0	2	0 161 6
# 28	21	0.0	2	0 0 21
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S252_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S252_3_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S252_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S252_3_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S252_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S252_3_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S252_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S252_3_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        62,127 reads  @     69.4 µs/read;   0.87 M reads/minute
# Finished in 4.31 s (69 us/read; 0.86 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             62,127
#   Read 1 with adapter:                  62,050 (99.9%)
#   Read 2 with adapter:                  61,983 (99.8%)
# Pairs written (passing filters):        62,127 (100.0%)
#
# Total basepairs processed:    36,651,992 bp
#   Read 1:    18,326,787 bp
#   Read 2:    18,325,205 bp
# Total written (filtered):     33,428,109 bp (91.2%)
#   Read 1:    16,713,544 bp
#   Read 2:    16,714,565 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 62050 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	41	0.0	2	0 0 41
# 25	457	0.0	2	0 442 15
# 26	61180	0.0	2	59245 1887 48
# 27	262	0.0	2	0 253 9
# 28	110	0.0	2	0 0 110
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 61983 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	89	0.0	2	0 0 89
# 25	1032	0.0	2	0 999 33
# 26	60577	0.0	2	59179 1351 47
# 27	278	0.0	2	0 265 13
# 28	7	0.0	2	0 0 7
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S253_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S253_5_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S253_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S253_5_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S253_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S253_5_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S253_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S253_5_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        53,830 reads  @     71.0 µs/read;   0.84 M reads/minute
# Finished in 3.83 s (71 us/read; 0.84 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             53,830
#   Read 1 with adapter:                  53,755 (99.9%)
#   Read 2 with adapter:                  53,702 (99.8%)
# Pairs written (passing filters):        53,830 (100.0%)
#
# Total basepairs processed:    31,756,516 bp
#   Read 1:    15,879,630 bp
#   Read 2:    15,876,886 bp
# Total written (filtered):     28,963,519 bp (91.2%)
#   Read 1:    14,482,038 bp
#   Read 2:    14,481,481 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 53755 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	46	0.0	2	0 0 46
# 25	387	0.0	2	0 377 10
# 26	52980	0.0	2	51261 1672 47
# 27	243	0.0	2	0 239 4
# 28	99	0.0	2	0 0 99
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 53702 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	89	0.0	2	0 0 89
# 25	919	0.0	2	0 899 20
# 26	52454	0.0	2	51262 1161 31
# 27	230	0.0	2	0 217 13
# 28	10	0.0	2	0 0 10
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S254_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S254_7_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S254_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S254_7_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S254_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S254_7_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S254_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S254_7_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:02        34,257 reads  @     81.4 µs/read;   0.74 M reads/minute
# Finished in 2.79 s (82 us/read; 0.74 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             34,257
#   Read 1 with adapter:                  34,215 (99.9%)
#   Read 2 with adapter:                  34,087 (99.5%)
# Pairs written (passing filters):        34,257 (100.0%)
#
# Total basepairs processed:    20,198,540 bp
#   Read 1:    10,105,561 bp
#   Read 2:    10,092,979 bp
# Total written (filtered):     18,423,313 bp (91.2%)
#   Read 1:     9,216,124 bp
#   Read 2:     9,207,189 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 34215 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	20	0.0	2	0 0 20
# 25	301	0.0	2	0 288 13
# 26	33735	0.0	2	32651 1050 34
# 27	130	0.0	2	0 128 2
# 28	29	0.0	2	0 0 29
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 34087 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	35	0.0	2	0 0 35
# 25	550	0.0	2	0 531 19
# 26	33359	0.0	2	32493 833 33
# 27	138	0.0	2	0 129 9
# 28	5	0.0	2	0 0 5
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S255_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S255_9_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S255_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S255_9_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S255_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S255_9_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S255_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S255_9_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:03        39,440 reads  @     88.2 µs/read;   0.68 M reads/minute
# Finished in 3.48 s (88 us/read; 0.68 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             39,440
#   Read 1 with adapter:                  39,385 (99.9%)
#   Read 2 with adapter:                  37,218 (94.4%)
# Pairs written (passing filters):        39,440 (100.0%)
#
# Total basepairs processed:    22,805,159 bp
#   Read 1:    11,633,658 bp
#   Read 2:    11,171,501 bp
# Total written (filtered):     20,814,368 bp (91.3%)
#   Read 1:    10,609,788 bp
#   Read 2:    10,204,580 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 39385 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	30	0.0	2	0 0 30
# 25	309	0.0	2	0 297 12
# 26	38865	0.0	2	37669 1170 26
# 27	133	0.0	2	0 129 4
# 28	48	0.0	2	0 0 48
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 37218 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	62	0.0	2	0 0 62
# 25	789	0.0	2	0 758 31
# 26	36209	0.0	2	35329 854 26
# 27	150	0.0	2	0 143 7
# 28	8	0.0	2	0 0 8
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S256_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S256_11_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S256_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S256_11_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S256_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S256_11_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S256_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S256_11_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        47,723 reads  @     89.5 µs/read;   0.67 M reads/minute
# Finished in 4.27 s (90 us/read; 0.67 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             47,723
#   Read 1 with adapter:                  47,650 (99.8%)
#   Read 2 with adapter:                  47,529 (99.6%)
# Pairs written (passing filters):        47,721 (100.0%)
#
# Total basepairs processed:    28,143,456 bp
#   Read 1:    14,077,353 bp
#   Read 2:    14,066,103 bp
# Total written (filtered):     25,669,355 bp (91.2%)
#   Read 1:    12,838,167 bp
#   Read 2:    12,831,188 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 47650 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	33	0.0	2	0 0 33
# 25	422	0.0	2	0 413 9
# 26	46995	0.0	2	45523 1432 40
# 27	164	0.0	2	0 160 4
# 28	36	0.0	2	0 0 36
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 47529 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	93	0.0	2	0 0 93
# 25	845	0.0	2	0 826 19
# 26	46404	0.0	2	45316 1051 37
# 27	182	0.0	2	0 175 7
# 28	5	0.0	2	0 0 5
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S257_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S257_13_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S257_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S257_13_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S257_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S257_13_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S257_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S257_13_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        56,870 reads  @     84.0 µs/read;   0.71 M reads/minute
# Finished in 4.78 s (84 us/read; 0.71 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             56,870
#   Read 1 with adapter:                  56,790 (99.9%)
#   Read 2 with adapter:                  56,782 (99.8%)
# Pairs written (passing filters):        56,870 (100.0%)
#
# Total basepairs processed:    33,547,054 bp
#   Read 1:    16,774,963 bp
#   Read 2:    16,772,091 bp
# Total written (filtered):     30,595,322 bp (91.2%)
#   Read 1:    15,298,629 bp
#   Read 2:    15,296,693 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 56790 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	42	0.0	2	0 0 42
# 25	397	0.0	2	0 391 6
# 26	56127	0.0	2	54507 1581 39
# 27	173	0.0	2	0 165 8
# 28	51	0.0	2	0 0 51
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 56782 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	78	0.0	2	0 0 78
# 25	1015	0.0	2	0 992 23
# 26	55460	0.0	2	54269 1164 27
# 27	221	0.0	2	0 215 6
# 28	8	0.0	2	0 0 8
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S258_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S258_15_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S258_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S258_15_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S258_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S258_15_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S258_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S258_15_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        55,189 reads  @     77.8 µs/read;   0.77 M reads/minute
# Finished in 4.30 s (78 us/read; 0.77 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             55,189
#   Read 1 with adapter:                  55,119 (99.9%)
#   Read 2 with adapter:                  55,078 (99.8%)
# Pairs written (passing filters):        55,189 (100.0%)
#
# Total basepairs processed:    32,560,239 bp
#   Read 1:    16,280,447 bp
#   Read 2:    16,279,792 bp
# Total written (filtered):     29,695,976 bp (91.2%)
#   Read 1:    14,847,484 bp
#   Read 2:    14,848,492 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 55119 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	28	0.0	2	0 0 28
# 25	397	0.0	2	0 390 7
# 26	54439	0.0	2	52850 1548 41
# 27	188	0.0	2	0 181 7
# 28	67	0.0	2	0 0 67
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 55078 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	59	0.0	2	0 0 59
# 25	840	0.0	2	0 821 19
# 26	53974	0.0	2	52822 1118 34
# 27	180	0.0	2	0 173 7
# 28	25	0.0	2	0 0 25
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S259_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S259_17_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S259_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S259_17_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S259_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S259_17_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S259_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S259_17_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        55,113 reads  @     79.3 µs/read;   0.76 M reads/minute
# Finished in 4.37 s (79 us/read; 0.76 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             55,113
#   Read 1 with adapter:                  55,045 (99.9%)
#   Read 2 with adapter:                  54,966 (99.7%)
# Pairs written (passing filters):        55,113 (100.0%)
#
# Total basepairs processed:    32,515,219 bp
#   Read 1:    16,257,941 bp
#   Read 2:    16,257,278 bp
# Total written (filtered):     29,655,857 bp (91.2%)
#   Read 1:    14,826,879 bp
#   Read 2:    14,828,978 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 55045 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	26	0.0	2	0 0 26
# 25	420	0.0	2	0 409 11
# 26	54303	0.0	2	52554 1688 61
# 27	228	0.0	2	0 224 4
# 28	68	0.0	2	0 0 68
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 54966 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	98	0.0	2	0 0 98
# 25	927	0.0	2	0 902 25
# 26	53675	0.0	2	52575 1059 41
# 27	225	0.0	2	0 213 12
# 28	41	0.0	2	0 0 41
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S260_18_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S260_19_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S260_18_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S260_19_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S260_18_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S260_19_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S260_18_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S260_19_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        43,246 reads  @     72.8 µs/read;   0.82 M reads/minute
# Finished in 3.15 s (73 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             43,246
#   Read 1 with adapter:                  43,169 (99.8%)
#   Read 2 with adapter:                  43,137 (99.7%)
# Pairs written (passing filters):        43,246 (100.0%)
#
# Total basepairs processed:    25,512,748 bp
#   Read 1:    12,757,270 bp
#   Read 2:    12,755,478 bp
# Total written (filtered):     23,269,602 bp (91.2%)
#   Read 1:    11,635,024 bp
#   Read 2:    11,634,578 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 43169 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	15	0.0	2	0 0 15
# 25	370	0.0	2	0 357 13
# 26	42583	0.0	2	41141 1400 42
# 27	150	0.0	2	0 146 4
# 28	51	0.0	2	0 0 51
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 43137 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	71	0.0	2	0 0 71
# 25	715	0.0	2	0 703 12
# 26	42163	0.0	2	41151 983 29
# 27	181	0.0	2	0 175 6
# 28	7	0.0	2	0 0 7
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S261_20_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S261_21_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S261_20_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S261_21_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S261_20_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S261_21_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S261_20_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S261_21_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        47,797 reads  @     71.4 µs/read;   0.84 M reads/minute
# Finished in 3.42 s (72 us/read; 0.84 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             47,797
#   Read 1 with adapter:                  47,718 (99.8%)
#   Read 2 with adapter:                  47,719 (99.8%)
# Pairs written (passing filters):        47,796 (100.0%)
#
# Total basepairs processed:    28,196,437 bp
#   Read 1:    14,099,812 bp
#   Read 2:    14,096,625 bp
# Total written (filtered):     25,715,498 bp (91.2%)
#   Read 1:    12,859,296 bp
#   Read 2:    12,856,202 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 47718 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	29	0.0	2	0 0 29
# 25	403	0.0	2	0 390 13
# 26	47047	0.0	2	45401 1613 33
# 27	169	0.0	2	0 161 8
# 28	70	0.0	2	0 0 70
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 47719 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	59	0.0	2	0 0 59
# 25	609	0.0	2	0 589 20
# 26	46866	0.0	2	45851 992 23
# 27	183	0.0	2	0 174 9
# 28	2	0.0	2	0 0 2
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S262_22_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S262_23_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S262_22_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S262_23_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S262_22_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S262_23_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S262_22_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S262_23_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        45,787 reads  @     71.3 µs/read;   0.84 M reads/minute
# Finished in 3.27 s (71 us/read; 0.84 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             45,787
#   Read 1 with adapter:                  45,732 (99.9%)
#   Read 2 with adapter:                  45,518 (99.4%)
# Pairs written (passing filters):        45,786 (100.0%)
#
# Total basepairs processed:    26,988,157 bp
#   Read 1:    13,507,158 bp
#   Read 2:    13,480,999 bp
# Total written (filtered):     24,615,930 bp (91.2%)
#   Read 1:    12,317,925 bp
#   Read 2:    12,298,005 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 45732 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	23	0.0	2	0 0 23
# 25	345	0.0	2	0 336 9
# 26	45107	0.0	2	43729 1334 44
# 27	191	0.0	2	0 186 5
# 28	66	0.0	2	0 0 66
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 45518 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	35	0.0	2	0 0 35
# 25	556	0.0	2	0 532 24
# 26	44777	0.0	2	43790 936 51
# 27	148	0.0	2	0 145 3
# 28	2	0.0	2	0 0 2
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S263_24_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S263_25_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S263_24_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S263_25_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S263_24_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S263_25_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S263_24_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S263_25_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        47,933 reads  @     83.9 µs/read;   0.71 M reads/minute
# Finished in 4.03 s (84 us/read; 0.71 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             47,933
#   Read 1 with adapter:                       0 (0.0%)
#   Read 2 with adapter:                  47,538 (99.2%)
# Pairs written (passing filters):        47,932 (100.0%)
#
# Total basepairs processed:    28,154,146 bp
#   Read 1:    14,077,073 bp
#   Read 2:    14,077,073 bp
# Total written (filtered):     26,918,845 bp (95.6%)
#   Read 1:    14,077,073 bp
#   Read 2:    12,841,772 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 0 times
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 47538 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	57	0.0	2	0 0 57
# 25	774	0.0	2	0 751 23
# 26	46519	0.0	2	45433 1035 51
# 27	175	0.0	2	0 165 10
# 28	13	0.0	2	0 0 13
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S264_26_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S264_27_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S264_26_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S264_27_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S264_26_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S264_27_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S264_26_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S264_27_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        48,209 reads  @     84.2 µs/read;   0.71 M reads/minute
# Finished in 4.07 s (84 us/read; 0.71 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             48,209
#   Read 1 with adapter:                  48,145 (99.9%)
#   Read 2 with adapter:                  48,059 (99.7%)
# Pairs written (passing filters):        48,207 (100.0%)
#
# Total basepairs processed:    28,423,171 bp
#   Read 1:    14,221,650 bp
#   Read 2:    14,201,521 bp
# Total written (filtered):     25,922,109 bp (91.2%)
#   Read 1:    12,969,480 bp
#   Read 2:    12,952,629 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 48145 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	31	0.0	2	0 0 31
# 25	395	0.0	2	0 386 9
# 26	47477	0.0	2	45748 1679 50
# 27	165	0.0	2	0 157 8
# 28	77	0.0	2	0 0 77
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 48059 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	71	0.0	2	0 0 71
# 25	717	0.0	2	0 705 12
# 26	47068	0.0	2	45952 1093 23
# 27	189	0.0	2	0 180 9
# 28	14	0.0	2	0 0 14
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S265_28_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S265_29_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S265_28_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S265_29_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S265_28_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S265_29_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S265_28_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S265_29_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        46,096 reads  @     74.5 µs/read;   0.81 M reads/minute
# Finished in 3.44 s (75 us/read; 0.80 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             46,096
#   Read 1 with adapter:                  46,020 (99.8%)
#   Read 2 with adapter:                  45,996 (99.8%)
# Pairs written (passing filters):        46,096 (100.0%)
#
# Total basepairs processed:    27,192,507 bp
#   Read 1:    13,597,758 bp
#   Read 2:    13,594,749 bp
# Total written (filtered):     24,801,112 bp (91.2%)
#   Read 1:    12,401,521 bp
#   Read 2:    12,399,591 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 46020 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	32	0.0	2	0 0 32
# 25	415	0.0	2	0 397 18
# 26	45417	0.0	2	43901 1469 47
# 27	116	0.0	2	0 110 6
# 28	40	0.0	2	0 0 40
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 45996 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	53	0.0	2	0 0 53
# 25	860	0.0	2	0 834 26
# 26	44868	0.0	2	43836 994 38
# 27	202	0.0	2	0 194 8
# 28	13	0.0	2	0 0 13
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S266_30_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S266_31_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S266_30_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S266_31_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S266_30_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S266_31_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S266_30_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S266_31_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        52,616 reads  @     73.3 µs/read;   0.82 M reads/minute
# Finished in 3.86 s (73 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             52,616
#   Read 1 with adapter:                  52,547 (99.9%)
#   Read 2 with adapter:                  52,493 (99.8%)
# Pairs written (passing filters):        52,616 (100.0%)
#
# Total basepairs processed:    31,042,444 bp
#   Read 1:    15,521,543 bp
#   Read 2:    15,520,901 bp
# Total written (filtered):     28,312,224 bp (91.2%)
#   Read 1:    14,155,525 bp
#   Read 2:    14,156,699 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 52547 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	30	0.0	2	0 0 30
# 25	419	0.0	2	0 409 10
# 26	51863	0.0	2	50262 1550 51
# 27	195	0.0	2	0 188 7
# 28	40	0.0	2	0 0 40
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 52493 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	61	0.0	2	0 0 61
# 25	734	0.0	2	0 717 17
# 26	51498	0.0	2	50381 1079 38
# 27	160	0.0	2	0 154 6
# 28	40	0.0	2	0 0 40
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S267_32_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S267_33_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S267_32_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S267_33_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S267_32_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S267_33_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S267_32_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S267_33_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:05        65,888 reads  @     76.9 µs/read;   0.78 M reads/minute
# Finished in 5.07 s (77 us/read; 0.78 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             65,888
#   Read 1 with adapter:                  65,717 (99.7%)
#   Read 2 with adapter:                  65,744 (99.8%)
# Pairs written (passing filters):        65,888 (100.0%)
#
# Total basepairs processed:    38,866,280 bp
#   Read 1:    19,430,148 bp
#   Read 2:    19,436,132 bp
# Total written (filtered):     35,449,271 bp (91.2%)
#   Read 1:    17,721,547 bp
#   Read 2:    17,727,724 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 65717 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	42	0.0	2	0 0 42
# 25	439	0.0	2	0 422 17
# 26	64868	0.0	2	62768 2054 46
# 27	254	0.0	2	0 246 8
# 28	114	0.0	2	0 0 114
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 65744 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	95	0.0	2	0 0 95
# 25	1098	0.0	2	0 1065 33
# 26	64215	0.0	2	62630 1533 52
# 27	320	0.0	2	0 309 11
# 28	16	0.0	2	0 0 16
#
# ...
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        58,285 reads  @     70.3 µs/read;   0.85 M reads/minute
# Finished in 4.10 s (70 us/read; 0.85 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             58,285
#   Read 1 with adapter:                  58,216 (99.9%)
#   Read 2 with adapter:                  58,165 (99.8%)
# Pairs written (passing filters):        58,285 (100.0%)
#
# Total basepairs processed:    34,381,721 bp
#   Read 1:    17,192,992 bp
#   Read 2:    17,188,729 bp
# Total written (filtered):     31,356,849 bp (91.2%)
#   Read 1:    15,679,593 bp
#   Read 2:    15,677,256 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 58216 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	23	0.0	2	0 0 23
# 25	484	0.0	2	0 468 16
# 26	57453	0.0	2	55460 1933 60
# 27	199	0.0	2	0 192 7
# 28	57	0.0	2	0 0 57
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 58165 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	83	0.0	2	0 0 83
# 25	930	0.0	2	0 900 30
# 26	56891	0.0	2	55461 1389 41
# 27	243	0.0	2	0 236 7
# 28	18	0.0	2	0 0 18
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S365_228_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S365_229_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S365_228_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S365_229_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S365_228_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S365_229_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S365_228_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S365_229_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        59,367 reads  @     67.8 µs/read;   0.88 M reads/minute
# Finished in 4.03 s (68 us/read; 0.88 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             59,367
#   Read 1 with adapter:                  59,298 (99.9%)
#   Read 2 with adapter:                  59,204 (99.7%)
# Pairs written (passing filters):        59,367 (100.0%)
#
# Total basepairs processed:    35,021,096 bp
#   Read 1:    17,512,704 bp
#   Read 2:    17,508,392 bp
# Total written (filtered):     31,941,214 bp (91.2%)
#   Read 1:    15,971,264 bp
#   Read 2:    15,969,950 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 59298 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	31	0.0	2	0 0 31
# 25	550	0.0	2	0 530 20
# 26	58453	0.0	2	56499 1912 42
# 27	224	0.0	2	0 219 5
# 28	40	0.0	2	0 0 40
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 59204 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	65	0.0	2	0 0 65
# 25	938	0.0	2	0 909 29
# 26	58002	0.0	2	56686 1281 35
# 27	192	0.0	2	0 186 6
# 28	7	0.0	2	0 0 7
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S366_230_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S366_231_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S366_230_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S366_231_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S366_230_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S366_231_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S366_230_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S366_231_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8<----------] 00:00:00         1,236 reads  @     98.1 µs/read;   0.61 M reads/minute
# Finished in 0.12 s (100 us/read; 0.60 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              1,236
#   Read 1 with adapter:                   1,235 (99.9%)
#   Read 2 with adapter:                   1,235 (99.9%)
# Pairs written (passing filters):         1,236 (100.0%)
#
# Total basepairs processed:       729,240 bp
#   Read 1:       364,620 bp
#   Read 2:       364,620 bp
# Total written (filtered):        665,051 bp (91.2%)
#   Read 1:       332,520 bp
#   Read 2:       332,531 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 1235 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	2	0.0	2	0 0 2
# 25	11	0.0	2	0 11
# 26	1217	0.0	2	1165 46 6
# 27	5	0.0	2	0 5
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 1235 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	2	0.0	2	0 0 2
# 25	25	0.0	2	0 23 2
# 26	1203	0.0	2	1165 37 1
# 27	2	0.0	2	0 2
# 28	3	0.0	2	0 0 3
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S367_232_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S367_233_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S367_232_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S367_233_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S367_232_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S367_233_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S367_232_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S367_233_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        51,511 reads  @     70.3 µs/read;   0.85 M reads/minute
# Finished in 3.62 s (70 us/read; 0.85 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             51,511
#   Read 1 with adapter:                  51,407 (99.8%)
#   Read 2 with adapter:                  51,413 (99.8%)
# Pairs written (passing filters):        51,511 (100.0%)
#
# Total basepairs processed:    30,383,594 bp
#   Read 1:    15,189,773 bp
#   Read 2:    15,193,821 bp
# Total written (filtered):     27,711,370 bp (91.2%)
#   Read 1:    13,853,594 bp
#   Read 2:    13,857,776 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 51407 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	37	0.0	2	0 0 37
# 25	712	0.0	2	0 693 19
# 26	50380	0.0	2	48642 1686 52
# 27	173	0.0	2	0 168 5
# 28	105	0.0	2	0 0 105
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 51413 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	65	0.0	2	0 0 65
# 25	813	0.0	2	0 788 25
# 26	50300	0.0	2	49129 1144 27
# 27	220	0.0	2	0 213 7
# 28	15	0.0	2	0 0 15
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S368_234_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S368_235_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S368_234_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S368_235_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S368_234_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S368_235_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S368_234_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S368_235_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        61,047 reads  @     68.4 µs/read;   0.88 M reads/minute
# Finished in 4.18 s (68 us/read; 0.88 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             61,047
#   Read 1 with adapter:                  60,965 (99.9%)
#   Read 2 with adapter:                  60,926 (99.8%)
# Pairs written (passing filters):        61,047 (100.0%)
#
# Total basepairs processed:    36,012,491 bp
#   Read 1:    18,006,531 bp
#   Read 2:    18,005,960 bp
# Total written (filtered):     32,844,940 bp (91.2%)
#   Read 1:    16,422,104 bp
#   Read 2:    16,422,836 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 60965 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	50	0.0	2	0 0 50
# 25	858	0.0	2	0 827 31
# 26	59810	0.0	2	57523 2219 68
# 27	199	0.0	2	0 188 11
# 28	48	0.0	2	0 0 48
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 60926 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	97	0.0	2	0 0 97
# 25	1118	0.0	2	0 1073 45
# 26	59400	0.0	2	57765 1592 43
# 27	262	0.0	2	0 255 7
# 28	49	0.0	2	0 0 49
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S369_236_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S369_237_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S369_236_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S369_237_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S369_236_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-4cxx_gj3/S369_237_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S369_236_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-5o5hqirw/c44e5724-a0ba-42ff-b188-1fef6bfa4a0f/data/S369_237_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        57,748 reads  @     84.1 µs/read;   0.71 M reads/minute
# Finished in 4.86 s (84 us/read; 0.71 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             57,748
#   Read 1 with adapter:                  57,628 (99.8%)
#   Read 2 with adapter:                  57,607 (99.8%)
# Pairs written (passing filters):        57,748 (100.0%)
#
# Total basepairs processed:    34,059,910 bp
#   Read 1:    17,027,974 bp
#   Read 2:    17,031,936 bp
# Total written (filtered):     31,065,509 bp (91.2%)
#   Read 1:    15,530,409 bp
#   Read 2:    15,535,100 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 57628 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	44	0.0	2	0 0 44
# 25	886	0.0	2	0 859 27
# 26	56517	0.0	2	54457 2005 55
# 27	151	0.0	2	0 144 7
# 28	30	0.0	2	0 0 30
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 57607 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	94	0.0	2	0 0 94
# 25	998	0.0	2	0 974 24
# 26	56286	0.0	2	55037 1211 38
# 27	218	0.0	2	0 214 4
# 28	11	0.0	2	0 0 11
# Saved SampleData[PairedEndSequencesWithQuality] to: COI_2-demux-pairedend-trimmed1.qza

# %%
#Import the fastq files into a QIIME2 artifact 

# !qiime tools import \
  --type 'SampleData[PairedEndSequencesWithQuality]' \
  --input-path leray_manifest_r3.csv \
  --output-path COI_3-paired-end-demux.qza \
  --input-format PairedEndFastqManifestPhred33
# !qiime cutadapt trim-paired \
    --i-demultiplexed-sequences COI_3-paired-end-demux.qza \
    --p-front-f '^GGWACWGGWTGAACWGTWTAYCCYCC' \
    --p-front-r '^TANACYTCNGGRTGNCCRAARAAYCA' \
    --o-trimmed-sequences COI_3-demux-pairedend-trimmed1.qza \
    --verbose
# Out:
# Imported leray_manifest_r3.csv as PairedEndFastqManifestPhred33 to COI_3-paired-end-demux.qza
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s651_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s651_148_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s651_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s651_148_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s651_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s651_148_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s651_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s651_148_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        46,266 reads  @     78.9 µs/read;   0.76 M reads/minute
# Finished in 3.66 s (79 us/read; 0.76 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             46,266
#   Read 1 with adapter:                  46,252 (100.0%)
#   Read 2 with adapter:                  45,940 (99.3%)
# Pairs written (passing filters):        46,266 (100.0%)
#
# Total basepairs processed:    27,291,190 bp
#   Read 1:    13,647,696 bp
#   Read 2:    13,643,494 bp
# Total written (filtered):     24,894,621 bp (91.2%)
#   Read 1:    12,445,335 bp
#   Read 2:    12,449,286 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 46252 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	31	0.0	2	0 0 31
# 25	503	0.0	2	0 487 16
# 26	45420	0.0	2	44628 782 10
# 27	222	0.0	2	0 221 1
# 28	76	0.0	2	0 0 76
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 45940 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	17	0.0	2	0 0 17
# 25	447	0.0	2	0 438 9
# 26	45265	0.0	2	44407 824 34
# 27	173	0.0	2	0 172 1
# 28	38	0.0	2	0 0 38
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s652_1_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s652_149_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s652_1_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s652_149_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s652_1_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s652_149_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s652_1_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s652_149_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        48,738 reads  @     74.5 µs/read;   0.81 M reads/minute
# Finished in 3.64 s (75 us/read; 0.80 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             48,738
#   Read 1 with adapter:                  48,721 (100.0%)
#   Read 2 with adapter:                  48,548 (99.6%)
# Pairs written (passing filters):        48,738 (100.0%)
#
# Total basepairs processed:    28,740,402 bp
#   Read 1:    14,376,991 bp
#   Read 2:    14,363,411 bp
# Total written (filtered):     26,211,818 bp (91.2%)
#   Read 1:    13,110,543 bp
#   Read 2:    13,101,275 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 48721 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	34	0.0	2	0 0 34
# 25	617	0.0	2	0 593 24
# 26	47760	0.0	2	46576 1167 17
# 27	233	0.0	2	0 226 7
# 28	77	0.0	2	0 0 77
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 48548 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	20	0.0	2	0 0 20
# 25	410	0.0	2	0 396 14
# 26	47836	0.0	2	46675 1127 34
# 27	226	0.0	2	0 221 5
# 28	56	0.0	2	0 0 56
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s653_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s653_150_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s653_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s653_150_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s653_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s653_150_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s653_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s653_150_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        44,346 reads  @     72.9 µs/read;   0.82 M reads/minute
# Finished in 3.24 s (73 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             44,346
#   Read 1 with adapter:                  44,326 (100.0%)
#   Read 2 with adapter:                  44,284 (99.9%)
# Pairs written (passing filters):        44,346 (100.0%)
#
# Total basepairs processed:    26,155,282 bp
#   Read 1:    13,081,138 bp
#   Read 2:    13,074,144 bp
# Total written (filtered):     23,851,912 bp (91.2%)
#   Read 1:    11,929,027 bp
#   Read 2:    11,922,885 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 44326 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	26	0.0	2	0 0 26
# 25	562	0.0	2	0 554 8
# 26	43511	0.0	2	42648 850 13
# 27	205	0.0	2	0 203 2
# 28	22	0.0	2	0 0 22
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 44284 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	16	0.0	2	0 0 16
# 25	315	0.0	2	0 309 6
# 26	43731	0.0	2	42898 801 32
# 27	222	0.0	2	0 217 5
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s654_3_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s654_151_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s654_3_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s654_151_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s654_3_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s654_151_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s654_3_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s654_151_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        52,599 reads  @     73.5 µs/read;   0.82 M reads/minute
# Finished in 3.87 s (74 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             52,599
#   Read 1 with adapter:                  52,576 (100.0%)
#   Read 2 with adapter:                  52,569 (99.9%)
# Pairs written (passing filters):        52,599 (100.0%)
#
# Total basepairs processed:    31,030,621 bp
#   Read 1:    15,515,143 bp
#   Read 2:    15,515,478 bp
# Total written (filtered):     28,297,408 bp (91.2%)
#   Read 1:    14,148,611 bp
#   Read 2:    14,148,797 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 52576 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	31	0.0	2	0 0 31
# 25	687	0.0	2	0 664 23
# 26	51588	0.0	2	50502 1065 21
# 27	235	0.0	2	0 227 8
# 28	35	0.0	2	0 0 35
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 52569 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	14	0.0	2	0 0 14
# 25	356	0.0	2	0 348 8
# 26	51932	0.0	2	50694 1195 43
# 27	263	0.0	2	0 254 9
# 28	4	0.0	2	0 0 4
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s655_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s655_152_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s655_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s655_152_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s655_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s655_152_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s655_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s655_152_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        54,431 reads  @     72.2 µs/read;   0.83 M reads/minute
# Finished in 3.93 s (72 us/read; 0.83 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             54,431
#   Read 1 with adapter:                  54,406 (100.0%)
#   Read 2 with adapter:                  54,383 (99.9%)
# Pairs written (passing filters):        54,431 (100.0%)
#
# Total basepairs processed:    32,107,193 bp
#   Read 1:    16,054,379 bp
#   Read 2:    16,052,814 bp
# Total written (filtered):     29,279,433 bp (91.2%)
#   Read 1:    14,640,219 bp
#   Read 2:    14,639,214 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 54406 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	29	0.0	2	0 0 29
# 25	659	0.0	2	0 634 25
# 26	53436	0.0	2	52402 1014 20
# 27	243	0.0	2	0 238 5
# 28	39	0.0	2	0 0 39
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 54383 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	31	0.0	2	0 0 31
# 25	573	0.0	2	0 554 19
# 26	53506	0.0	2	52437 1035 34
# 27	269	0.0	2	0 265 4
# 28	4	0.0	2	0 0 4
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s656_5_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s656_153_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s656_5_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s656_153_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s656_5_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s656_153_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s656_5_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s656_153_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        50,641 reads  @     75.3 µs/read;   0.80 M reads/minute
# Finished in 3.82 s (75 us/read; 0.80 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             50,641
#   Read 1 with adapter:                  50,624 (100.0%)
#   Read 2 with adapter:                  50,565 (99.8%)
# Pairs written (passing filters):        50,641 (100.0%)
#
# Total basepairs processed:    29,867,067 bp
#   Read 1:    14,938,450 bp
#   Read 2:    14,928,617 bp
# Total written (filtered):     27,236,702 bp (91.2%)
#   Read 1:    13,622,579 bp
#   Read 2:    13,614,123 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 50624 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	30	0.0	2	0 0 30
# 25	610	0.0	2	0 595 15
# 26	49708	0.0	2	48690 1006 12
# 27	235	0.0	2	0 228 7
# 28	41	0.0	2	0 0 41
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 50565 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	18	0.0	2	0 0 18
# 25	443	0.0	2	0 428 15
# 26	49823	0.0	2	48869 925 29
# 27	279	0.0	2	0 269 10
# 28	2	0.0	2	0 0 2
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s657_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s657_154_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s657_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s657_154_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s657_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s657_154_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s657_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s657_154_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        56,200 reads  @     74.7 µs/read;   0.80 M reads/minute
# Finished in 4.20 s (75 us/read; 0.80 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             56,200
#   Read 1 with adapter:                  56,170 (99.9%)
#   Read 2 with adapter:                  56,130 (99.9%)
# Pairs written (passing filters):        56,200 (100.0%)
#
# Total basepairs processed:    33,151,548 bp
#   Read 1:    16,577,301 bp
#   Read 2:    16,574,247 bp
# Total written (filtered):     30,232,425 bp (91.2%)
#   Read 1:    15,117,315 bp
#   Read 2:    15,115,110 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 56170 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	28	0.0	2	0 0 28
# 25	678	0.0	2	0 648 30
# 26	55200	0.0	2	54058 1129 13
# 27	228	0.0	2	0 225 3
# 28	36	0.0	2	0 0 36
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 56130 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	24	0.0	2	0 0 24
# 25	444	0.0	2	0 432 12
# 26	55414	0.0	2	54344 1048 22
# 27	247	0.0	2	0 245 2
# 28	1	0.0	2	0 0 1
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s658_7_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s658_155_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s658_7_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s658_155_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s658_7_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s658_155_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s658_7_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s658_155_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        47,828 reads  @     77.0 µs/read;   0.78 M reads/minute
# Finished in 3.69 s (77 us/read; 0.78 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             47,828
#   Read 1 with adapter:                  47,807 (100.0%)
#   Read 2 with adapter:                  47,787 (99.9%)
# Pairs written (passing filters):        47,828 (100.0%)
#
# Total basepairs processed:    28,217,071 bp
#   Read 1:    14,108,190 bp
#   Read 2:    14,108,881 bp
# Total written (filtered):     25,732,182 bp (91.2%)
#   Read 1:    12,865,613 bp
#   Read 2:    12,866,569 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 47807 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	24	0.0	2	0 0 24
# 25	637	0.0	2	0 608 29
# 26	46900	0.0	2	45868 1017 15
# 27	212	0.0	2	0 208 4
# 28	34	0.0	2	0 0 34
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 47787 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	13	0.0	2	0 0 13
# 25	345	0.0	2	0 337 8
# 26	47213	0.0	2	46368 829 16
# 27	211	0.0	2	0 207 4
# 28	5	0.0	2	0 0 5
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s659_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s659_156_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s659_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s659_156_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s659_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s659_156_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s659_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s659_156_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        40,810 reads  @     75.9 µs/read;   0.79 M reads/minute
# Finished in 3.10 s (76 us/read; 0.79 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             40,810
#   Read 1 with adapter:                  40,784 (99.9%)
#   Read 2 with adapter:                  40,444 (99.1%)
# Pairs written (passing filters):        40,809 (100.0%)
#
# Total basepairs processed:    24,070,189 bp
#   Read 1:    12,036,780 bp
#   Read 2:    12,033,409 bp
# Total written (filtered):     21,958,636 bp (91.2%)
#   Read 1:    10,976,804 bp
#   Read 2:    10,981,832 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 40784 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	35	0.0	2	0 0 35
# 25	594	0.0	2	0 578 16
# 26	39924	0.0	2	39023 881 20
# 27	206	0.0	2	0 198 8
# 28	25	0.0	2	0 0 25
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 40444 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	15	0.0	2	0 0 15
# 25	408	0.0	2	0 393 15
# 26	39820	0.0	2	38990 793 37
# 27	200	0.0	2	0 196 4
# 28	1	0.0	2	0 0 1
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s660_9_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s660_157_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s660_9_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s660_157_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s660_9_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s660_157_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s660_9_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s660_157_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        46,351 reads  @     68.8 µs/read;   0.87 M reads/minute
# Finished in 3.20 s (69 us/read; 0.87 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             46,351
#   Read 1 with adapter:                  46,328 (100.0%)
#   Read 2 with adapter:                  46,298 (99.9%)
# Pairs written (passing filters):        46,349 (100.0%)
#
# Total basepairs processed:    27,342,504 bp
#   Read 1:    13,670,932 bp
#   Read 2:    13,671,572 bp
# Total written (filtered):     24,934,289 bp (91.2%)
#   Read 1:    12,466,878 bp
#   Read 2:    12,467,411 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 46328 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	34	0.0	2	0 0 34
# 25	693	0.0	2	0 672 21
# 26	45348	0.0	2	44363 970 15
# 27	219	0.0	2	0 214 5
# 28	34	0.0	2	0 0 34
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 46298 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	23	0.0	2	0 0 23
# 25	363	0.0	2	0 359 4
# 26	45633	0.0	2	44636 962 35
# 27	274	0.0	2	0 265 9
# 28	5	0.0	2	0 0 5
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s661_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s661_158_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s661_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s661_158_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s661_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s661_158_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s661_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s661_158_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:02        38,340 reads  @     71.3 µs/read;   0.84 M reads/minute
# Finished in 2.74 s (71 us/read; 0.84 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             38,340
#   Read 1 with adapter:                  38,320 (99.9%)
#   Read 2 with adapter:                  38,294 (99.9%)
# Pairs written (passing filters):        38,339 (100.0%)
#
# Total basepairs processed:    22,611,737 bp
#   Read 1:    11,308,842 bp
#   Read 2:    11,302,895 bp
# Total written (filtered):     20,619,954 bp (91.2%)
#   Read 1:    10,312,861 bp
#   Read 2:    10,307,093 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 38320 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	23	0.0	2	0 0 23
# 25	538	0.0	2	0 513 25
# 26	37540	0.0	2	36692 832 16
# 27	193	0.0	2	0 189 4
# 28	26	0.0	2	0 0 26
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 38294 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	6	0.0	2	0 0 6
# 25	292	0.0	2	0 285 7
# 26	37805	0.0	2	37064 720 21
# 27	189	0.0	2	0 184 5
# 28	2	0.0	2	0 0 2
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s662_11_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s662_159_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s662_11_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s662_159_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s662_11_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s662_159_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s662_11_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s662_159_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:02        39,429 reads  @     74.7 µs/read;   0.80 M reads/minute
# Finished in 2.95 s (75 us/read; 0.80 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             39,429
#   Read 1 with adapter:                  39,383 (99.9%)
#   Read 2 with adapter:                  39,392 (99.9%)
# Pairs written (passing filters):        39,429 (100.0%)
#
# Total basepairs processed:    23,260,326 bp
#   Read 1:    11,630,167 bp
#   Read 2:    11,630,159 bp
# Total written (filtered):     21,212,579 bp (91.2%)
#   Read 1:    10,606,507 bp
#   Read 2:    10,606,072 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 39383 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	32	0.0	2	0 0 32
# 25	508	0.0	2	0 497 11
# 26	38602	0.0	2	37722 860 20
# 27	208	0.0	2	0 203 5
# 28	33	0.0	2	0 0 33
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 39392 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	10	0.0	2	0 0 10
# 25	285	0.0	2	0 279 6
# 26	38903	0.0	2	38014 848 41
# 27	188	0.0	2	0 180 8
# 28	6	0.0	2	0 0 6
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s663_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s663_160_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s663_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s663_160_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s663_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s663_160_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s663_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s663_160_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:02        43,996 reads  @     67.5 µs/read;   0.89 M reads/minute
# Finished in 2.98 s (68 us/read; 0.89 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             43,996
#   Read 1 with adapter:                  43,968 (99.9%)
#   Read 2 with adapter:                  43,964 (99.9%)
# Pairs written (passing filters):        43,996 (100.0%)
#
# Total basepairs processed:    25,954,805 bp
#   Read 1:    12,977,332 bp
#   Read 2:    12,977,473 bp
# Total written (filtered):     23,669,306 bp (91.2%)
#   Read 1:    11,834,646 bp
#   Read 2:    11,834,660 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 43968 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	36	0.0	2	0 0 36
# 25	646	0.0	2	0 622 24
# 26	43079	0.0	2	42106 958 15
# 27	178	0.0	2	0 173 5
# 28	29	0.0	2	0 0 29
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 43964 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	18	0.0	2	0 0 18
# 25	466	0.0	2	0 458 8
# 26	43235	0.0	2	42367 844 24
# 27	239	0.0	2	0 234 5
# 28	6	0.0	2	0 0 6
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s664_13_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s664_161_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s664_13_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s664_161_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s664_13_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s664_161_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s664_13_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s664_161_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:02        43,135 reads  @     68.9 µs/read;   0.87 M reads/minute
# Finished in 2.98 s (69 us/read; 0.87 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             43,135
#   Read 1 with adapter:                  43,112 (99.9%)
#   Read 2 with adapter:                  43,051 (99.8%)
# Pairs written (passing filters):        43,134 (100.0%)
#
# Total basepairs processed:    25,436,380 bp
#   Read 1:    12,723,669 bp
#   Read 2:    12,712,711 bp
# Total written (filtered):     23,196,465 bp (91.2%)
#   Read 1:    11,603,154 bp
#   Read 2:    11,593,311 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 43112 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	29	0.0	2	0 0 29
# 25	620	0.0	2	0 601 19
# 26	42224	0.0	2	41293 913 18
# 27	197	0.0	2	0 192 5
# 28	42	0.0	2	0 0 42
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 43051 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	16	0.0	2	0 0 16
# 25	366	0.0	2	0 356 10
# 26	42467	0.0	2	41618 819 30
# 27	201	0.0	2	0 196 5
# 28	1	0.0	2	0 0 1
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s665_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s665_162_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s665_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s665_162_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s665_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s665_162_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s665_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s665_162_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:02        39,977 reads  @     70.7 µs/read;   0.85 M reads/minute
# Finished in 2.83 s (71 us/read; 0.85 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             39,977
#   Read 1 with adapter:                  39,946 (99.9%)
#   Read 2 with adapter:                  39,926 (99.9%)
# Pairs written (passing filters):        39,975 (100.0%)
#
# Total basepairs processed:    23,578,558 bp
#   Read 1:    11,790,284 bp
#   Read 2:    11,788,274 bp
# Total written (filtered):     21,501,952 bp (91.2%)
#   Read 1:    10,752,113 bp
#   Read 2:    10,749,839 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 39946 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	34	0.0	2	0 0 34
# 25	614	0.0	2	0 598 16
# 26	39068	0.0	2	38264 793 11
# 27	203	0.0	2	0 198 5
# 28	27	0.0	2	0 0 27
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 39926 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	14	0.0	2	0 0 14
# 25	334	0.0	2	0 322 12
# 26	39395	0.0	2	38612 759 24
# 27	183	0.0	2	0 178 5
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s666_15_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s666_163_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s666_15_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s666_163_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s666_15_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s666_163_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s666_15_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s666_163_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:02        41,162 reads  @     69.2 µs/read;   0.87 M reads/minute
# Finished in 2.85 s (69 us/read; 0.87 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             41,162
#   Read 1 with adapter:                  41,135 (99.9%)
#   Read 2 with adapter:                  41,127 (99.9%)
# Pairs written (passing filters):        41,162 (100.0%)
#
# Total basepairs processed:    24,283,338 bp
#   Read 1:    12,141,022 bp
#   Read 2:    12,142,316 bp
# Total written (filtered):     22,145,065 bp (91.2%)
#   Read 1:    11,071,887 bp
#   Read 2:    11,073,178 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 41135 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	41	0.0	2	0 0 41
# 25	578	0.0	2	0 557 21
# 26	40268	0.0	2	39351 904 13
# 27	211	0.0	2	0 207 4
# 28	37	0.0	2	0 0 37
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 41127 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	15	0.0	2	0 0 15
# 25	353	0.0	2	0 344 9
# 26	40542	0.0	2	39779 737 26
# 27	215	0.0	2	0 212 3
# 28	2	0.0	2	0 0 2
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s667_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s667_164_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s667_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s667_164_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s667_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s667_164_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s667_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s667_164_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        50,186 reads  @     75.1 µs/read;   0.80 M reads/minute
# Finished in 3.78 s (75 us/read; 0.80 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             50,186
#   Read 1 with adapter:                  49,651 (98.9%)
#   Read 2 with adapter:                  49,726 (99.1%)
# Pairs written (passing filters):        50,186 (100.0%)
#
# Total basepairs processed:    29,542,781 bp
#   Read 1:    14,745,440 bp
#   Read 2:    14,797,341 bp
# Total written (filtered):     26,959,591 bp (91.3%)
#   Read 1:    13,454,821 bp
#   Read 2:    13,504,770 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 49651 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	27	0.0	2	0 0 27
# 25	527	0.0	2	0 510 17
# 26	48859	0.0	2	47899 947 13
# 27	202	0.0	2	0 196 6
# 28	36	0.0	2	0 0 36
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 49726 times
#
# No. of allowed errors:
# ...
# Processing reads on 1 core in paired-end mode ...
# [  8<--------] 00:00:06        55,102 reads  @    109.2 µs/read;   0.55 M reads/minute
# Finished in 6.02 s (109 us/read; 0.55 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             55,102
#   Read 1 with adapter:                  55,079 (100.0%)
#   Read 2 with adapter:                  55,069 (99.9%)
# Pairs written (passing filters):        55,102 (100.0%)
#
# Total basepairs processed:    32,509,419 bp
#   Read 1:    16,254,809 bp
#   Read 2:    16,254,610 bp
# Total written (filtered):     29,645,946 bp (91.2%)
#   Read 1:    14,823,021 bp
#   Read 2:    14,822,925 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 55079 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	33	0.0	2	0 0 33
# 25	549	0.0	2	0 535 14
# 26	54202	0.0	2	52997 1182 23
# 27	241	0.0	2	0 235 6
# 28	54	0.0	2	0 0 54
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 55069 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	21	0.0	2	0 0 21
# 25	427	0.0	2	0 414 13
# 26	54277	0.0	2	53233 1015 29
# 27	328	0.0	2	0 327 1
# 28	16	0.0	2	0 0 16
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s795_143_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s795_291_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s795_143_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s795_291_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s795_143_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s795_291_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s795_143_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s795_291_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        49,425 reads  @     90.3 µs/read;   0.66 M reads/minute
# Finished in 4.47 s (90 us/read; 0.66 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             49,425
#   Read 1 with adapter:                  49,402 (100.0%)
#   Read 2 with adapter:                  49,376 (99.9%)
# Pairs written (passing filters):        49,425 (100.0%)
#
# Total basepairs processed:    29,155,428 bp
#   Read 1:    14,580,139 bp
#   Read 2:    14,575,289 bp
# Total written (filtered):     26,587,665 bp (91.2%)
#   Read 1:    13,295,911 bp
#   Read 2:    13,291,754 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 49402 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	25	0.0	2	0 0 25
# 25	456	0.0	2	0 437 19
# 26	48683	0.0	2	47715 954 14
# 27	194	0.0	2	0 186 8
# 28	44	0.0	2	0 0 44
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 49376 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	23	0.0	2	0 0 23
# 25	488	0.0	2	0 479 9
# 26	48587	0.0	2	47596 960 31
# 27	263	0.0	2	0 257 6
# 28	15	0.0	2	0 0 15
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s796_144_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s796_292_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s796_144_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s796_292_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s796_144_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s796_292_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s796_144_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s796_292_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:05        53,877 reads  @     93.1 µs/read;   0.64 M reads/minute
# Finished in 5.02 s (93 us/read; 0.64 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             53,877
#   Read 1 with adapter:                  53,860 (100.0%)
#   Read 2 with adapter:                  53,823 (99.9%)
# Pairs written (passing filters):        53,877 (100.0%)
#
# Total basepairs processed:    31,784,413 bp
#   Read 1:    15,893,692 bp
#   Read 2:    15,890,721 bp
# Total written (filtered):     28,985,112 bp (91.2%)
#   Read 1:    14,493,630 bp
#   Read 2:    14,491,482 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 53860 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	19	0.0	2	0 0 19
# 25	550	0.0	2	0 541 9
# 26	53041	0.0	2	51937 1087 17
# 27	210	0.0	2	0 203 7
# 28	40	0.0	2	0 0 40
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 53823 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	16	0.0	2	0 0 16
# 25	412	0.0	2	0 400 12
# 26	53118	0.0	2	52082 1001 35
# 27	269	0.0	2	0 264 5
# 28	8	0.0	2	0 0 8
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s797_145_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s797_293_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s797_145_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s797_293_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s797_145_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s797_293_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s797_145_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s797_293_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:04        54,737 reads  @     76.2 µs/read;   0.79 M reads/minute
# Finished in 4.18 s (76 us/read; 0.79 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             54,737
#   Read 1 with adapter:                  54,711 (100.0%)
#   Read 2 with adapter:                  54,707 (99.9%)
# Pairs written (passing filters):        54,737 (100.0%)
#
# Total basepairs processed:    32,293,120 bp
#   Read 1:    16,146,960 bp
#   Read 2:    16,146,160 bp
# Total written (filtered):     29,448,526 bp (91.2%)
#   Read 1:    14,724,697 bp
#   Read 2:    14,723,829 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 54711 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	22	0.0	2	0 0 22
# 25	561	0.0	2	0 545 16
# 26	53815	0.0	2	52698 1103 14
# 27	244	0.0	2	0 236 8
# 28	69	0.0	2	0 0 69
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 54707 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	14	0.0	2	0 0 14
# 25	423	0.0	2	0 417 6
# 26	53888	0.0	2	52827 1038 23
# 27	364	0.0	2	0 353 11
# 28	18	0.0	2	0 0 18
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s798_146_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s798_294_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s798_146_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s798_294_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s798_146_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s798_294_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s798_146_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s798_294_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        48,881 reads  @     79.6 µs/read;   0.75 M reads/minute
# Finished in 3.89 s (80 us/read; 0.75 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             48,881
#   Read 1 with adapter:                  48,804 (99.8%)
#   Read 2 with adapter:                  48,843 (99.9%)
# Pairs written (passing filters):        48,881 (100.0%)
#
# Total basepairs processed:    28,825,531 bp
#   Read 1:    14,406,800 bp
#   Read 2:    14,418,731 bp
# Total written (filtered):     26,287,065 bp (91.2%)
#   Read 1:    13,138,128 bp
#   Read 2:    13,148,937 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 48804 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	26	0.0	2	0 0 26
# 25	475	0.0	2	0 456 19
# 26	48053	0.0	2	47125 909 19
# 27	205	0.0	2	0 198 7
# 28	45	0.0	2	0 0 45
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 48843 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	20	0.0	2	0 0 20
# 25	351	0.0	2	0 340 11
# 26	48217	0.0	2	47237 947 33
# 27	243	0.0	2	0 238 5
# 28	12	0.0	2	0 0 12
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s799_147_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s799_295_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s799_147_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s799_295_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s799_147_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-plpcbwwt/s799_295_L001_R2_001.fastq.gz --front ^GGWACWGGWTGAACWGTWTAYCCYCC -G ^TANACYTCNGGRTGNCCRAARAAYCA /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s799_147_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-z0r330fh/67b3eaa1-d40a-4854-b126-dc2c9ea42fbd/data/s799_295_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8=----------] 00:00:02        27,387 reads  @     79.1 µs/read;   0.76 M reads/minute
# Finished in 2.17 s (79 us/read; 0.76 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             27,387
#   Read 1 with adapter:                  27,371 (99.9%)
#   Read 2 with adapter:                  27,139 (99.1%)
# Pairs written (passing filters):        27,387 (100.0%)
#
# Total basepairs processed:    16,154,137 bp
#   Read 1:     8,078,874 bp
#   Read 2:     8,075,263 bp
# Total written (filtered):     14,737,130 bp (91.2%)
#   Read 1:     7,367,342 bp
#   Read 2:     7,369,788 bp
#
# === First read: Adapter 1 ===
#
# Sequence: GGWACWGGWTGAACWGTWTAYCCYCC; Type: anchored 5'; Length: 26; Trimmed: 27371 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-26 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	9	0.0	2	0 0 9
# 25	271	0.0	2	0 263 8
# 26	26935	0.0	2	26249 672 14
# 27	137	0.0	2	0 134 3
# 28	19	0.0	2	0 0 19
#
#
# === Second read: Adapter 2 ===
#
# Sequence: TANACYTCNGGRTGNCCRAARAAYCA; Type: anchored 5'; Length: 26; Trimmed: 27139 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-23 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 24	15	0.0	2	0 0 15
# 25	298	0.0	2	0 286 12
# 26	26646	0.0	2	26041 588 17
# 27	171	0.0	2	0 165 6
# 28	9	0.0	2	0 0 9
# Saved SampleData[PairedEndSequencesWithQuality] to: COI_3-demux-pairedend-trimmed1.qza

# %%
# !qiime demux summarize \
  --i-data COI_2-demux-pairedend-trimmed1.qza \
  --o-visualization COI_2-demux-pairedend-trimmed1.qzv
# Out:
# Saved Visualization to: COI_2-demux-pairedend-trimmed1.qzv

# %%
# !qiime demux summarize \
  --i-data COI_3-demux-pairedend-trimmed1.qza \
  --o-visualization COI_3-demux-pairedend-trimmed1.qzv
# Out:
# Saved Visualization to: COI_3-demux-pairedend-trimmed1.qzv

# %%
q2.Visualization.load('COI_2-demux-pairedend-trimmed1.qzv')
# Out:
# <visualization: Visualization uuid: 6b3f54d8-15ff-4913-9a81-3b4dfbfaef7f>

# %%
q2.Visualization.load('COI_3-demux-pairedend-trimmed1.qzv')
# Out:
# <visualization: Visualization uuid: 2af65b28-a1a0-49c3-8242-b911d0a5a321>

# %%
#Generate ESVs (Exact Sequence Variants). QIIME2 has two packages available for this. We are using dada2 for our single end reads.
# NOTE: if you are wanting to do paired end reads, you'll use qiime dada2 denoise-paired (https://docs.qiime2.org/2019.7/plugins/available/dada2/denoise-paired/)
# NOTE: if you are wanting to join reads you'll have to use Deblur


# !qiime dada2 denoise-paired \
  --i-demultiplexed-seqs COI_2-demux-pairedend-trimmed1.qza \
  --p-trunc-len-f 265 \
  --p-trunc-len-r 235 \
  --p-pooling-method pseudo \
  --p-chimera-method consensus \
  --p-n-threads 0 \
  --p-n-reads-learn 10000 \
  --o-representative-sequences COI_2-paired-end-demux_rep-seqs-dada2.qza \
  --o-table COI_2-paired-end-demux_table-dada2.qza \
  --o-denoising-stats COI_2-paired-end-demux_stats-dada2.qza
# Out:
# Saved FeatureTable[Frequency] to: COI_2-paired-end-demux_table-dada2.qza
# Saved FeatureData[Sequence] to: COI_2-paired-end-demux_rep-seqs-dada2.qza
# Saved SampleData[DADA2Stats] to: COI_2-paired-end-demux_stats-dada2.qza

# %%
#Generate ESVs (Exact Sequence Variants). QIIME2 has two packages available for this. We are using dada2 for our single end reads.
# NOTE: if you are wanting to do paired end reads, you'll use qiime dada2 denoise-paired (https://docs.qiime2.org/2019.7/plugins/available/dada2/denoise-paired/)
# NOTE: if you are wanting to join reads you'll have to use Deblur


# !qiime dada2 denoise-paired \
  --i-demultiplexed-seqs COI_3-demux-pairedend-trimmed1.qza \
  --p-trunc-len-f 267 \
  --p-trunc-len-r 180 \
  --p-pooling-method pseudo \
  --p-chimera-method consensus \
  --p-n-threads 0 \
  --p-n-reads-learn 10000 \
  --o-representative-sequences COI_3-paired-end-demux_rep-seqs-dada2.qza \
  --o-table COI_3-paired-end-demux_table-dada2.qza \
  --o-denoising-stats COI_3-paired-end-demux_stats-dada2.qza
# Out:
# Saved FeatureTable[Frequency] to: COI_3-paired-end-demux_table-dada2.qza
# Saved FeatureData[Sequence] to: COI_3-paired-end-demux_rep-seqs-dada2.qza
# Saved SampleData[DADA2Stats] to: COI_3-paired-end-demux_stats-dada2.qza

# %%
#now merge the three runs
# !qiime feature-table merge \
  --i-tables COI_1-paired-end-demux_table-dada2.qza \
  --i-tables COI_2-paired-end-demux_table-dada2.qza \
  --i-tables COI_3-paired-end-demux_table-dada2.qza \
  --o-merged-table COI-paired-end-demux_table-dada2.qza
# !qiime feature-table merge-seqs \
  --i-data COI_1-paired-end-demux_rep-seqs-dada2.qza \
  --i-data COI_2-paired-end-demux_rep-seqs-dada2.qza \
  --i-data COI_3-paired-end-demux_rep-seqs-dada2.qza \
  --o-merged-data COI-paired-end-demux_rep-seqs-dada2.qza
# Out:
# Saved FeatureTable[Frequency] to: COI-paired-end-demux_table-dada2.qza
# Saved FeatureData[Sequence] to: COI-paired-end-demux_rep-seqs-dada2.qza

# %%
# The feature-table summarize command will give you information on how many sequences are associated with each sample and with each feature, histograms of those distributions, and some related summary statistics. 
# !qiime feature-table summarize \
  --i-table COI-paired-end-demux_table-dada2.qza \
  --o-visualization COI-table.qzv \
  
#--m-sample-metadata-file metadata_COI_clean.txt
# Out:
# Saved Visualization to: COI-table.qzv

# %%
#View the .qzv
q2.Visualization.load('COI-table.qzv')
# Out:
# <visualization: Visualization uuid: f34a3c5a-07e1-4711-85eb-d6cadad128e9>

# %%
# !qiime feature-table tabulate-seqs \
  --i-data  COI-paired-end-demux_rep-seqs-dada2.qza \
  --o-visualization COI-paired-end-demux_rep-seqs-dada2.qzv
# Out:
# Saved Visualization to: COI-paired-end-demux_rep-seqs-dada2.qzv

# %%
# !qiime vsearch cluster-features-de-novo \
  --i-table COI-paired-end-demux_table-dada2.qza \
  --i-sequences COI-paired-end-demux_rep-seqs-dada2.qza \
  --p-perc-identity 0.97 \
  --o-clustered-table  COI-paired-end-demux_table-dada2_vsearch97.qza \
  --o-clustered-sequences COI-paired-end-demux_rep-seqs-dada2_vsearch97.qza
# Out:
# Saved FeatureTable[Frequency] to: COI-paired-end-demux_table-dada2_vsearch97.qza
# Saved FeatureData[Sequence] to: COI-paired-end-demux_rep-seqs-dada2_vsearch97.qza

# %%
# !qiime feature-table tabulate-seqs \
  --i-data  COI-paired-end-demux_rep-seqs-dada2_vsearch97.qza  \
  --o-visualization COI-paired-end-demux_rep-seqs-dada2_vsearch97.qzv
# Out:
# Saved Visualization to: COI-paired-end-demux_rep-seqs-dada2_vsearch97.qzv

# %%
#View the .qzv
q2.Visualization.load('COI-paired-end-demux_rep-seqs-dada2_vsearch97.qzv')
# Out:
# <visualization: Visualization uuid: 900e20c8-ccd6-4dfc-8998-fcd8b241e8d3>

# %%
# !qiime feature-table summarize \
  --i-table COI-paired-end-demux_table-dada2_vsearch97.qza \
  --o-visualization COI-paired-end-demux_table-dada2_vsearch97.qzv \
 # --m-sample-metadata-file metadata_COI_clean.txt
# Out:
# Saved Visualization to: COI-paired-end-demux_table-dada2_vsearch97.qzv

# %%
#View the .qzv
q2.Visualization.load('COI-paired-end-demux_table-dada2_vsearch97.qzv')
# Out:
# <visualization: Visualization uuid: 3c85226b-65f1-4efd-9d30-13a55db700ef>

# %%
# !qiime tools export \
  --input-path COI-paired-end-demux_table-dada2_vsearch97.qza \
  --output-path exported-feature-table
# Out:
# Exported COI-paired-end-demux_table-dada2_vsearch97.qza as BIOMV210DirFmt to directory exported-feature-table

# %%
# !biom convert -i exported-feature-table/feature-table.biom -o COI_97vsearch_OTUtable.tsv --to-tsv

# %%
# !biom convert -i exported-feature-table/feature-table.biom -o exported-feature-table/feature-table_hdf5.biom --to-hdf5 --table-type="OTU table"

# %%
# !biom convert -i exported-feature-table/feature-table.biom -o exported-feature-table/feature-table_json.biom --to-json --table-type="OTU table"

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /Users/stephaniematthews/Documents/Chapter1/qiime2_analyses/midori_database/midori-classifier_untrimmed.qza \
  --i-reads COI-paired-end-demux_rep-seqs-dada2_vsearch97.qza \
  --o-classification COI-midori-sklearn-taxonomy_untrimmed.qza

# !qiime metadata tabulate \
  --m-input-file COI-midori-sklearn-taxonomy_untrimmed.qza \
  --o-visualization COI-midori-sklearn-taxonomy_untrimmed.qzv
# Out:
# Saved FeatureData[Taxonomy] to: COI-midori-sklearn-taxonomy_untrimmed.qza
# Saved Visualization to: COI-midori-sklearn-taxonomy_untrimmed.qzv

# %%
import qiime2 as q2
q2.Visualization.load('COI-midori-sklearn-taxonomy_untrimmed.qzv')
# Out:
# <visualization: Visualization uuid: 66772e9e-6edb-4c93-a6ab-fc59198d603b>

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-leray-classifier_r_trimmed.qza \
  --i-reads COI-paired-end-demux_rep-seqs-dada2_vsearch97.qza \
  --o-classification COI-MZGtrimmed-sklearn-taxonomy.qza

# !qiime metadata tabulate \
  --m-input-file COI-MZGtrimmed-sklearn-taxonomy.qza \
  --o-visualization COI-MZGtrimmed-sklearn-taxonomy.qzv

# %%
import qiime2 as q2
q2.Visualization.load('COI-MZGtrimmed-sklearn-taxonomy.qzv')
